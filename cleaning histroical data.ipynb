# %% [markdown]
# #  Install Needed Libraries

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.14.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.11.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.4.2)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.4)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.60.0)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 7.4 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 18.6 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 27.1 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.9 MB/s eta 0:00:00
# Downloading puremagic-1.28-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.6 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=e368444a80a15e3140c10dcae13cfb2e8f714181d7b32f732f2413e53e3a50f5
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, PyWavelets, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed PyWavelets-1.8.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.4 puremagic-1.28 visions-0.8.1 ydata-profiling-4.16.1

# %% [markdown]
# #Import Needed Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from ydata_profiling import ProfileReport

# %% [markdown]
# #  Exploratory Data Analysis (EDA)

# %%
# Reading the dataset
file_1=pd.read_csv('dataset1.csv')
df_1=file_1.copy()
file_2=pd.read_csv('dataset2.csv')
df_2=file_2.copy()

# %%
# Display the first few rows of the dataset
print(df_1.head())
print("      -----------------------------------------------------------------  ")
print(df_2.head())
# Out:
#                                Name                   Short description  \
# 0                    Vilém Pospíšil                    Baptist minister
# 1                   Elise Schmieden             schrijfster (1841-1896)
# 2                 Jerónimo de Rueda             Spanish baroque painter
# 3  August Karl Wilhelm Weissenbruch                       German author
# 4                     Gösta Göthlin  schwedischer Arzt und Bakteriologe
#
#   Gender Occupation  Age of death
# 0   Male     Pastor          73.0
# 1    NaN     Artist          55.0
# 2   Male     Artist          80.0
# 3   Male     Artist          82.0
# 4   Male  Physician          89.0
#       -----------------------------------------------------------------
#                  Name  Gender         Country  Birth year  Death year  \
# 0           Yin Buhai     NaN    Chen dynasty         505       589.0
# 1  Johann von Wickede     1.0             NaN        1664      1732.0
# 2     Frank McCashney     1.0       Australia        1890      1951.0
# 3        Hugo Berwald     1.0         Germany        1863      1937.0
# 4         Karel Fiala     1.0  Czechoslovakia        1871      1931.0
#
#   Manner of death
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Display basic information about the dataset
df_1.info()
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917131 entries, 0 to 917130
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Name               917131 non-null  object
#  1   Short description  866104 non-null  object
#  2   Gender             816763 non-null  object
#  3   Occupation         761744 non-null  object
#  4   Age of death       917130 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 35.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855989 entries, 0 to 855988
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Name             855989 non-null  object
#  1   Gender           762276 non-null  float64
#  2   Country          621522 non-null  object
#  3   Birth year       855989 non-null  int64
#  4   Death year       855989 non-null  float64
#  5   Manner of death  37566 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 39.2+ MB

# %%
#unique values in each cloumn
print("         dataset_1")
print(df_1.nunique())
print("-------------------------------")
print("         dataset_2")
print(df_2.nunique())
# Out:
#          dataset_1
# Name                 858685
# Short description    395709
# Gender                    2
# Occupation             7734
# Age of death            128
# dtype: int64
# -------------------------------
#          dataset_2
# Name               803759
# Gender                  2
# Country               971
# Birth year           2056
# Death year           2134
# Manner of death       142
# dtype: int64

# %%
print("         dataset_1")
print(df_1.isnull().sum())
print("-------------------------------")
print("         dataset_2")
print(df_2.isnull().sum())
# Out:
#          dataset_1
# Name                      0
# Short description     51027
# Gender               100368
# Occupation           155387
# Age of death              1
# dtype: int64
# -------------------------------
#          dataset_2
# Name                    0
# Gender              93713
# Country            234467
# Birth year              0
# Death year              0
# Manner of death    818423
# dtype: int64

# %%
print("dataset_1 unique gender ",df_1['Gender'].unique())
print("dataset_2 unique gender",df_2['Gender'].unique())
# Out:
# dataset_1 unique gender  ['Male' nan 'Female']
# dataset_2 unique gender [nan  1.  2.]

# %%
df_2['Country'].nunique()
# Out:
# 971

# %%
df_1['Occupation'].value_counts()
# Out:
# Occupation
# Artist                             210905
# Politician                         146448
# Athlete                             83047
# Researcher                          68068
# Military personnel                  39650
#                                     ...
# Activist; museum professional           1
# Impresario; television director         1
# Mosaicist; air force officer            1
# Chocolatier; type foundry               1
# Talent manager; publicist               1
# Name: count, Length: 7734, dtype: int64

# %% [markdown]
# #DataProfiling

# %%
profile_dataset_1 = ProfileReport(df_1)

# %%
profile_dataset_1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile_dataset_2 = ProfileReport(df_2)

# %%
profile_dataset_2
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Data Cleaning

# %%
short=df_1['Short description'].unique()
list(short)
# Out:
# ['Baptist minister',
#  'schrijfster (1841-1896)',
#  'Spanish baroque painter',
#  'German author',
#  'schwedischer Arzt und Bakteriologe',
#  'photographer',
#  'boekhandelaar',
#  'musician and poet (1965-1997)',
#  'German politician',
#  'Canadian politician',
#  'Russian priest',
#  'Continental Army and US Army general, US Secretary of War (1750-1806)',
#  'German jurist',
#  'German opera singer (1914-1997)',
#  'Norwegian WW2 resistance fighter',
#  'Canadian, 1803-1856; artist',
#  'Dutch university teacher',
#  'Peerage person ID=102225',
#  'Dominican friar who became an anti-Trinitarian',
#  'figure skater, discus thrower, football executive and engineer',
#  '(1886-1968) Christian Brother and schoolteacher',
#  'German lawyer and judge',
#  nan,
#  'escritor de non ficción danés (1822–1905)',
#  'Footballer (1930-1984)',
#  'Swiss politician (1440-1510)',
#  'American Freestyle Motocross rider',
#  'Spanish actor (1902–1982)',
#  'Finnish journalist',
#  'French railroad engineer',
#  'British biochemist',
#  'pfälzische Adelige, Benediktinerin, Äbtissin der Klöster Rupertsberg und Eibingen',
#  'Belgian bicycle racer',
#  'President of Argentina (1920-2015)',
#  'New Zealand geologist, mineralogist and professor (1910–1971)',
#  'prentkunstenaar',
#  'British musician',
#  'Basque ETA member',
#  'French general',
#  'English judge',
#  'Sheriff of Cheshire/1551',
#  'writer',
#  'American football player (1934-2004)',
#  'American musicians',
#  'Hunting, Sir Percy Llewellyn (1885–1973), shipping and aviation entrepreneur',
#  'Catholic Metropolitan of Lviv',
#  'wetenschapper',
#  'restaurateur',
#  'United States Navy Medal of Honor recipient',
#  'Spanish linguist (1802-1860)',
#  'socialite and writer; founder of Future Primitive Prodcasting',
#  'Italian painter (1619-1675)',
#  'American politician (1857-1935)',
#  'Polish geologist',
#  'Italian archbishop',
#  'Swedish translator',
#  'footballer (1915-1999)',
#  'English scholar of Italian',
#  'Dutch architect',
#  'ministru rusu (1932–2019)',
#  'French theater and film actress',
#  'politician and historian',
#  'French actress',
#  'American photography curator',
#  '(1798-1866)',
#  'kunstschilder',
#  'Italian painter (1798-1882)',
#  'German flying ace',
#  'monnik',
#  '1799-1848 , lawyer, editor, and Unitarian clergyman',
#  'Soviet and Russian actor',
#  'American actor',
#  'Polish officer',
#  'German writer (1934-2012)',
#  'American baseball player',
#  'Russisch Metalurg (1923-2016)',
#  'Japanese author (1921-1991)',
#  'Ukrainian military personnel',
#  'Scottish physician (1610–1681)',
#  'British zoologist',
#  'American, 1905–1998',
#  'American writer, editor, and USNO librarian',
#  'German painter (1891-1960)',
#  'German painter',
#  'Television documentary filmmaker',
#  'Independent minister (1777 -1833)',
#  'British politician',
#  'Australian singer and Aboriginal theatre administrator (1939-1976)',
#  'psychiater',
#  'American NASA administrator and President of Rensselaer Polytechnic Institute',
#  'German film director and film producer',
#  'Belgian philologist',
#  'schrijver uit Sovjet-Unie (1939-)',
#  'Spanish politician (1907-1943)',
#  'Haddow, Sir (Thomas) Douglas (1913–1986), civil servant',
#  'Producer, screenwriter, director, actor (1925-1995)',
#  'English evangelical clergyman',
#  'British colonial administrator',
#  'German conductor',
#  'Australian rules footballer, born 1893',
#  '( 1635 — 1711 )',
#  'Bulgarian artist (1925-2006)',
#  'German university teacher (1908-1997)',
#  'Spanish journalist (1925-2005)',
#  'médico e escritor galego',
#  'English physician',
#  'agrariër',
#  'Polish physicist',
#  'Australian anthropologist and archaeologist (1910-1992)',
#  'suo jure Grand Duchess of Luxembourg from 1919 to 1964',
#  'Association football winger (1903-1971)',
#  'Japanese scholar of Chinese literature',
#  'American businessman',
#  'Belgian geographer (1925-2012)',
#  'French politician',
#  '1884 bis 1971 Beruf/Funktion Herdfabrikant Konfession evangelischer Großvater Namensvarianten Küppersbusch, Fritz',
#  'Italian architect',
#  'American politician',
#  'Engliah painter (1837-1928)',
#  'German painter (1813-1888)',
#  'American congressman (1866-1940)',
#  'Dutch journalist',
#  'Czech painter (1802-1875)',
#  'Irish republican',
#  'Russian general (1828-1901)',
#  'Ukrainian poet, translator, classical and literature scholar',
#  'Czech actress',
#  'German entomologist and ichthyologist',
#  'antifascista e partigiano italiano',
#  'politician',
#  'Austrian painter (1848-1913)',
#  'pianist',
#  'French pharmacist and physician',
#  'French sculptor (1877-1967)',
#  'Brazilian writer',
#  'French mathematician',
#  'Turkish actor',
#  'médico español',
#  'architect',
#  'Dutch television presenter, radio dj, basketball player and presenter',
#  'American jazz and rhythm and blues saxophonist, bandleader and occasional vocalist',
#  'Finnish architect',
#  'American actor, drama teacher, acting coach, theorist (1901-1982)',
#  'American academic',
#  'English politician',
#  'American businessman and politician',
#  'German politician (1838-1921)',
#  'wife of science fiction author Clifford Simak',
#  'Italian basketball player',
#  '조선 중후기의 문신',
#  'German philologist',
#  'non-fictieschrijver',
#  'British actor (1887-1957)',
#  "43º Gran Maestro dell'Ordine di Livonia",
#  'American filmmaker (1917-1961)',
#  'Norwegian cross-country skier',
#  'Italian sculptor (1871-1915)',
#  'actor',
#  'American physician',
#  'Urdu writer',
#  'French association football player (1903-1966)',
#  'African-American physician',
#  '日本の江戸時代の公家',
#  'British and Indian Army officer 1915 to 1954',
#  'Frans vertaler (1873-1952)',
#  'British photographer in London, 1834-1901',
#  'Dutch politician (1917-2011)',
#  'American writer (1891-1968)',
#  'Player of American football (1976-2005)',
#  'German politician and lawyer (1773-1853)',
#  'Swiss entrepreneur (1898-1995)',
#  'French noble',
#  'Czech stage, film and dubbing actor and university educator',
#  'German composer',
#  'astronomer',
#  'Czechoslovak member of Czechoslovak national parliament, german nation politician and publicist',
#  'German-Danish General',
#  'طبيب توليد ونساء من روسيا البيضاء',
#  'archiveru polacu (1877–1950)',
#  'Irish politician and lawyer',
#  'Finnish writer',
#  'American politician (1865-1951)',
#  'advocaat uit Hertogdom Savoye (1818-1872)',
#  'American football player (1930-2009)',
#  'Turkish politician',
#  'Church of Scotland minister, died 1783',
#  'Chilean painter (1880-1967)',
#  'United States federal judge',
#  'Hungarian ethnographer',
#  'Umpire (1943-1989)',
#  'American pool player',
#  'Austrian journalist',
#  'British classical philologist',
#  'Hungarian chess player',
#  'British painter (1863-1924)',
#  'Austrian historian of technology',
#  'militair',
#  'Polish politician and deputy',
#  '(1587-1644)',
#  'German politician (1921–2002)',
#  'American historian',
#  'Japanese Shogi player',
#  'American painter, 1877-1939',
#  'Soviet flying ace',
#  'American painter',
#  '(1775-1842)',
#  'German psychotherapist',
#  'George Nicholas Loggin (1882-1955) 1955 Obituary &amp;#91;1&amp;#93;',
#  'American journalist',
#  'American magazine editor',
#  'American art historian',
#  'American bluegrass musician, songwriter',
#  'Polish general (1873-1960)',
#  'American anthropologist',
#  'Norwegian football player (1895-1969)',
#  'Swiss sculptor',
#  'American mayor',
#  'Tang dynasty person CBDB = 189288',
#  'Danish judge (1838-1916)',
#  'professional golfer',
#  'double agent',
#  'Italian engineer',
#  'Hungarian conductor and politician',
#  'Canadian education philosopher',
#  'British politician (1909-1989)',
#  'German architect',
#  'member of the Swiss Federal Council (1914-1995)',
#  'Russian association football player (1942-2001)',
#  'Yiddish author',
#  'British architect',
#  'Czech sport publicist',
#  'deutscher Porzellan-, Dekorations-, Historien- und Porträtmaler sowie Zeichner und Kupferstecher',
#  'Canadian writer',
#  'German middle distance runner',
#  'Austrian opera singer',
#  'homeopaat',
#  'German chemist',
#  'American actor and comedian (1922-1987)',
#  'Australian rules footballer',
#  'English footballer (1904-1929)',
#  'German journalist',
#  'British civil servant & cartoonist',
#  'inventor noruegu (1895–1961)',
#  'French sculptor and illustrator (1878-1951)',
#  'Mexican politician and lawyer (1811-1853)',
#  'Genevan politician (1652-1728)',
#  "German fighter ace and Knight's Cross recipient",
#  'Italian banker',
#  'cartoonist',
#  '(1855-1935)',
#  'French motorcycle racer',
#  'Argentine politician; governor of Corrientes province',
#  'Italian automobile designer',
#  'Swiss officer (1910-1992)',
#  'Czechoslovak senator of Czechoslovak National Parliament and Czechoslovak politician',
#  'artista testil noruega (1922–2003)',
#  'U.S. politician (1796-1857)',
#  'roman-catholic bishop',
#  'British sinologist and diplomatic interpreter from Chinese',
#  'English cricketer (1880-1950)',
#  'British writer',
#  'Australian rules footballer and coach',
#  'Soviet military personnel',
#  'Russian painter',
#  'German amtshauptmann',
#  'German-born American painter',
#  'roman-catholic archbishop',
#  'Italian Servant of God',
#  'translator of Greek and Roman classics',
#  'Czech music educator, composer, painter and choirmaster (1858-1950)',
#  'Spanish politician',
#  'Welsh surgeon and missionary',
#  'German officer',
#  'Mexican politician',
#  'director de teatre i televisió valencià',
#  'British writer-musician',
#  'Swiss economist (1929-2018)',
#  'journalist',
#  'baseball player from the United States',
#  '(1916-2003)',
#  'mathematician',
#  'Saudi Arabian physician',
#  'Danish sculptor',
#  'rijke Amsterdamse vrouw en bezitter van onroerend goed aan de Amsterdamse grachten',
#  'President of Nicaragua (1925-1980)',
#  'German count',
#  'cyclist',
#  '1715 bis 1775 Beruf/Funktion evangelischer Theologe Konfession evangelisch Namensvarianten Kohlreif, Christoph Gotthilf',
#  'English association football player (1966-2019)',
#  'American architect',
#  'English footballer (1901-1993)',
#  'rugby union player',
#  'Belgian politician',
#  'Canadian missionary',
#  'French diplomat',
#  'German politician (1887-1949)',
#  'American suffragist',
#  'American musician',
#  'kunstenaar',
#  'Art historian',
#  'Australian chemist',
#  '1604-1678',
#  'Czech translator and university educator',
#  'Recipient of the Victoria Cross',
#  'Polish actor',
#  'Italian pastor in England and Switzerland',
#  'American racing driver',
#  'Polish architect',
#  'member of the Bengal Civil Service (1868-93)',
#  'English naturalist',
#  'Belgian humorist (1933-2015)',
#  'American sculptor',
#  'American actor (1950-2015)',
#  'Japanese baseball player',
#  'Belgian actor',
#  'American neuroscientist',
#  'American cardiologist',
#  'Italian politician',
#  'American baseball player and coach',
#  'United States Navy admiral',
#  'Iraqi-Canadian physician, surgeon and academic',
#  'German political scientist',
#  'New Zealand mayor',
#  'German classical philologist and librarian',
#  'muzikant',
#  'Canadian sportscaster',
#  '(17. sz.) erdélyi diplomata',
#  'Russian economist',
#  'Polish author and teacher',
#  'Hellenistic Jewish historian (fl. ca. 100 BCE), who wrote a lost history of the times of the Maccabees down to the victory over Nicanor (175-161 BCE); mentioned in 2 Macc.',
#  'French politician (1838-1916)',
#  'Ukrainian bishop',
#  '(1886-1946) mosaic manufacturer',
#  'Irish missionary',
#  'Italian artist (1764-1834)',
#  'Pakistani Islamic Scholar',
#  'Swiss educationalist (1924-2017)',
#  'Japanese politician',
#  'Argentinian actor',
#  'japonský hrabě',
#  'kunsthandelaar',
#  'actor, director, designer and illustrator from France',
#  'German inventor, engineer and entrepreneur',
#  'American fighter pilot',
#  'Swedish politician',
#  'English writer and magazine editor',
#  'American football player and coach',
#  'deutsche BDM-Scharführerin, die 1944/45 als Symbol der gefürchteten fanatischen Hitlerjugend galt',
#  'Danish historian',
#  'Footballer (1950-1992)',
#  'oficial francés (1736–1807)',
#  'Belgian museum director',
#  'Canadian tennis player',
#  '1840 bis 1901 Beruf/Funktion Pädagoge und Autor ; Seminardirektor am Lehrerseminar Rickenbach in Schwyz ; Pfarrer in Wettingen ; Kaplan der Schweizergarde in Rom ; päpstlicher Geheimkämmerer Konfession katholisch Namensvarianten Marty, Johann',
#  'Finnish painter and stained glass artist (1909-2002)',
#  'Spanish writer',
#  'Polish journalist (1919-1982)',
#  'Scottish courtier and landowner',
#  'English cleric, Dean of Hereford 1613-1692',
#  'German engineer',
#  'Dutch computer scientist',
#  'British racing driver',
#  'bayerischer Staatsmann',
#  'British steam locomotive engineer and author',
#  'Italian painter (1442-1518)',
#  'politician, died 1857',
#  'illustrator',
#  'South African politician (1830-1913)',
#  'Slovene film director',
#  'Austrian teacher and classical philologist',
#  'Scottish local historian',
#  'Prime Minister of Luxembourg (1817-1904)',
#  "Slovenian poet, translator, resistance fighter, and Yugoslav people's hero",
#  '1858 bis 1904 Beruf/Funktion Philologe ; Mathematiker ; Gymnasialprofessor in Stuttgart Konfession evangelischer Sohn Namensvarianten Leins, Johannes',
#  'officier',
#  'Swedish actress',
#  'French playwright (1909-1982)',
#  'French privateer and page',
#  'American economist',
#  'British chemist',
#  'British academic',
#  'French architect',
#  'English writer on silver',
#  'German politician and jurist',
#  'svensk affärsman',
#  'Spanish journalist',
#  'British Army general',
#  'Estonian pulmonologist',
#  'Australian politician',
#  'Deutscher Parteifunktionär der KPD und NS-Widerstandskämpfer',
#  'French composer',
#  'Costa Rican politician',
#  '1854-1924',
#  'radziecki polityk',
#  'Finnish scientist',
#  'Russian historian',
#  'Soviet cinematographer ans screenwriter',
#  'French sculptor',
#  'American Mormon leader',
#  'South Korean actress (1980–2007)',
#  'Russisch kunstschilder (1858-1920)',
#  '(1865-1908)',
#  '(1756-1808)',
#  'German librarian, author and theologian',
#  'Chief Rabbi of Denmark (1833-1891)',
#  'Polish actress',
#  'auteur',
#  'German literary historian',
#  '(1421-1493)',
#  'American diplomat',
#  'Italian Catholic bishop',
#  'Welsh Baptist minister and Biblical scholar',
#  'French boxer',
#  'polnischer Sportler',
#  'American bobsledder',
#  'Irish Bishop',
#  'Japanese mangaka',
#  'Austrian stonemason and entrepreneur',
#  'French painter (1664-1749)',
#  'American singer',
#  'Irish rebel',
#  'Norwegian writer',
#  'British illustrator and landscape painter (1875-1960)',
#  'German artist and photographer',
#  'German actor',
#  'naaktmodel uit Keizerrijk Rusland (1869-1952)',
#  'American settler',
#  'Norwegian politician',
#  '1658-1723; Titles or roles: prebendary of Winchester, 1712; rector of Wonston, Hampshire, 1710; precentor of Exeter, 1706; canon of Exeter, 1693',
#  'Swedish paleontologist',
#  'French military personnel',
#  'English footballer (1907-1982)',
#  'fourth wife of William the Silent (1555-1620)',
#  'uitgever',
#  'Ukrainian writer (1902-1936)',
#  'aerospace engineer from the United States',
#  'French racing driver',
#  'German theatre director',
#  'Austrian stage actor and writer (1789-1869)',
#  'Northern Irish footballer (1900-1969)',
#  'Italian architect and urban planner',
#  'American politician (1788-1859)',
#  'componist',
#  'politicus',
#  'English zoologist, ornithologist, and lawyer',
#  'Spaans advocaat (1939-2000)',
#  'German politician (1844-1914)',
#  'English cricketer and chartered accountant (1937-2019)',
#  'German actor (1971-1997)',
#  'Spanish broadcaster',
#  'norwegischer Rennfahrer und Techniker',
#  'South African jurist',
#  'German physicist',
#  '(1846-1880)',
#  'Spanish writer (1818-1890)',
#  'American football player',
#  'American pathologist',
#  'Born: 26 March 1862 in Bleienbach, Bern canton, Switzerland; Died: 1 November 1922',
#  'Belgian politician (1925-2012)',
#  'Indian philosopher',
#  'Irish surgeon',
#  'presbitero italiano (1869 -1896)',
#  'onderwijzer',
#  'naturalist',
#  'American actress (1924-2019)',
#  'Saxonian noble woman',
#  'Irish footballer and manager (1928-2002)',
#  'Latvian painter',
#  'American World War II pilot',
#  '1915-1944, soldier for Estonia and Germany',
#  'Russian cinematographer',
#  'French catholic priest',
#  'German botanist (1940-2018)',
#  "Women's rights advocacy",
#  'French aviator during World War I',
#  'Portuguese feminist politician, founder of the Movement for the Liberation of Women (Movimento de Libertação das Mulheres)',
#  'Romanian historian and activist',
#  'Irish Republican',
#  'Italian association football player (1912-1997)',
#  'American composer and arts administrator (1910-1992)',
#  'field hockey player',
#  'bewerker',
#  'Hawaiian politician',
#  'Marxist economist and philosopher (1899-1990)',
#  'russischer Feldherr',
#  'German politician (1925-1981)',
#  'US-amerikanischer Segelschiffskapitän',
#  'basketball player',
#  'American politician (1816-1879)',
#  'Swedish official and politician (1843–1924)',
#  'Brazilian priest',
#  'Soviet singer',
#  '1795-1863',
#  'Romanian historian',
#  'German sculptor and painter (1876-1914)',
#  'English organist',
#  'cricketer (1914-2001)',
#  'American chemist',
#  'Austrian chemist',
#  'German judge, politician and jurist (1909-1989)',
#  'schrijver',
#  'English peer',
#  'American author, editor, and playwright',
#  'Russian footballer (1937-1981)',
#  'Dutch football player (1949-1995)',
#  'German-Swiss jurist and pacifist',
#  'United States Army Medal of Honor recipient',
#  'Mauritian trade unionist',
#  'Irish politician',
#  '日本の武士、陸軍軍人',
#  'Dutch resistance fighter in World War II',
#  'wrestler',
#  'Austrian bacteriologist',
#  'American vaudeville performer',
#  'German actor, director, dramaturge and writer',
#  'German politician (1767-1822)',
#  'dänischer Phonetiker',
#  'editor de periódicu israelín (1901–1975)',
#  'italienischer Dirigent',
#  'drug trafficker',
#  'médicu español (1643–1704)',
#  'polnischer Sänger',
#  'Czech composer and publicist',
#  '(1923-1989)',
#  'German byzantinist and high school teacher',
#  'ornithologist',
#  'American football player (1880-1932)',
#  'Italian diplomat (1593-1646)',
#  'French noble and Superintendent of Finances of France from 1623 to 1653',
#  'Finnish politician',
#  '(1872-1965), County council chairman and businessman',
#  'Canadian artist (1920-2010)',
#  'British bookbinder',
#  'Cameroonian writer, poet and playwright (1954-2016)',
#  'український науковець, освітянин',
#  'French writer',
#  'British painter',
#  'Armenian politician',
#  'French activist',
#  "poorter en schepen van 's-Hertogenbosch",
#  'impresor francés (1479–1537)',
#  'Italian entrepreneur',
#  'Sri Lankan judge',
#  'American psychoanalyst',
#  'Soviet film director (1918-1989)',
#  'director de cine uruguayo',
#  'Slovene painter',
#  'Japanese actor',
#  'Polish writer',
#  'German military personnel',
#  'Czech playwright, scriptwriter and writer',
#  'British Indian Army general',
#  'Australian sports administrator',
#  'deutscher Rittergutsbesitzer und Hofbeamter',
#  'Mayor of Trois-Rivières, Québec, Canada, 1970–1990',
#  'Scottish advocate and journalist',
#  'American composer',
#  'Zweeds sporter (1923-2003)',
#  'beeldhouwer uit Heilige Roomse Rijk (1686-1733)',
#  'Argentine politician (1863-1951)',
#  'German swimmer',
#  'inventor alemán (1913–1985)',
#  'Norwegian diplomat',
#  'Swedish association football player (1935-2004)',
#  'preußischer Oberst, Chef des Garnisons-Regiments Nr. 9',
#  'Lyn Arthur Philip Harris (1892-1916) 1916 Obituary &amp;#91;1&amp;#93; Captain IAN ARTHUR PHILIP HARRIS, Welsh Regiment, was born at Llanishen, Cardiff, on 9t...',
#  'German writer',
#  'Brazilian politician',
#  '1869 bis 1916 Beruf/Funktion Jurist ; Publizist ; Rechtsanwalt in Danzig ; Herausgeber von "Sächsischer Volkswart" Konfession katholischer Vater Namensvarianten Kloeppel, Friedrich',
#  'Chinese empress',
#  'deutscher Anwalt und Parlamentarier',
#  'Spanish ambassador, diplomat and military personnel (1905-1987)',
#  '1856 bis 1938 Geburtsort Oeynhausen Sterbeort Düsseldorf Beruf/Funktion Eisenhüttenmann Konfession evangelisch Namensvarianten Sültenmeyer, Gottlieb Heinrich Wilhelm (eigentlich) Sültenmeyer, Fritz Sültenmeyer, Gottlieb Heinrich Wilhelm (eigentl',
#  'Polish translator, journalist and film actor (1911-1972)',
#  'British intelligent officer',
#  'British nutritional epidemiologist',
#  'French cinematographer',
#  'Italian painter (1788-1865)',
#  'historian',
#  'Chinese historian and politician',
#  'Japanese architect',
#  'Ghanaian politician',
#  'Catholic cardinal',
#  'deutscher Pädagoge und Historiker',
#  'адмирал',
#  'Belgian painter',
#  'French joiner-cabinetmaker and woodcarver based in Colmar in Alsace',
#  'French actor',
#  'British Patent attorney (1842-1892)',
#  'Portuguese explorer',
#  '1819 - 1902',
#  'Dutch chemist (1886-1958)',
#  '1401-1500',
#  'Polish mathematician',
#  'British missionary in Taiwan',
#  'Norwegian painter (1938-2007)',
#  'American politician (1902-1971)',
#  'Duchess of York',
#  'American football player, end (1932-2016)',
#  'comte allemand',
#  'academicus',
#  'Austrian painter (1817-1883)',
#  'Member of the Queensland Legislative Council',
#  'Canadian scientist, physician and professor',
#  'French jurist-consultant',
#  'Brazilian lawyer, journalist and politician, former mayor of the city of João Pessoa',
#  'American football player (1933-2017)',
#  'German politician (1875-1950)',
#  'American religious leader',
#  'British sculptor (1834-1890)',
#  'Belgian film director',
#  'Spanish painter (1923-2012)',
#  'Swedish swimmer',
#  'bishop of Milan; one of the four original doctors of the Church (339-397)',
#  'Independent Oil and Gas Businessman',
#  'German politician (1912-1979)',
#  'German politician (1900-1971)',
#  'literatuurhistoricus',
#  'English legal writer and judge',
#  'cricketer (1892-1963)',
#  'Muslim admiral',
#  'Austrian screenwriter and writer (1890-1965)',
#  'Japanese photographer',
#  'Paraguayan poet',
#  'actress (1882-1928)',
#  'Japanese painter',
#  'American physician, author and historian from Pennsylvania',
#  '(1833-1874)',
#  'eesti filmioperaator ja -produtsent',
#  'Italian poet and writer',
#  'American politician (1783-1870)',
#  'Welsh Baptist minister and schoolmaster (1875-1944)',
#  '(1892-1981)',
#  'bishop',
#  'British locomotive engineer',
#  'Chinese musician',
#  'roman-catholic patriarch',
#  'Sri Lankan politician',
#  'ondernemer',
#  'American stock car racing driver',
#  'German librarian, historian and art historian',
#  'Portuguese bishop',
#  '1952-2013',
#  '1714-1777',
#  'German neurologist',
#  'French historian',
#  'British political economist',
#  'association football player (1890-1916)',
#  'Russian flying ace',
#  'Mexican sculptor and painter (1909-1953)',
#  'American rabbi and author',
#  'naval architect and designer',
#  'American basketball player',
#  'British politician (1786-1855)',
#  'British priest',
#  'American politician (1849-1908)',
#  '(1854-1918)',
#  'Brazilian actor',
#  'English cricketer (1912-1982)',
#  'American Mesoamericanist',
#  'Scottish locomotive engineer and manufacturer',
#  'American boxer',
#  'musician',
#  'Hong Kong politician',
#  'Recipient of the Purple Heart medal',
#  'acteur uit Letland (1893-1979)',
#  'Norwegian ceramist',
#  'productor de radio xaponés (1930–2002)',
#  'Chinese military personnel',
#  'Soviet sculptor (1896-1947)',
#  'lieutenant general in the United States Army',
#  'Welsh cricketer, born 1939',
#  'New Zealand steeplechase runner',
#  'French woodcarver and organbuilder',
#  'Swedish artist',
#  'Czech banker and politician',
#  'Spanish architect',
#  'German theologian',
#  'Australian poet',
#  'immigration agent (1857-1925)',
#  'Hungarian essayist',
#  'English printseller (1763-1830)',
#  'Turkish general',
#  'British film, television and stage actor (1902-1983)',
#  'actress (1911-1956)',
#  'German singer and opera singer',
#  'Chilean civil engineer',
#  'Chilean priest',
#  'writer and activist',
#  'English marine painter',
#  'swimmer',
#  'British physicist',
#  'Hungarian-born painter who lived and worked in the United States',
#  'nobre brasileiro',
#  'Italian painter and engraver (1845-1906)',
#  'American clergyman',
#  '1770 - 1845',
#  'French officer',
#  'American football player and coach (1895-1952)',
#  'Australian Army officer',
#  '1861 bis 1909 Beruf/Funktion pharmazeutischer Chemiker Konfession - Namensvarianten Partheil, Alfred',
#  'French woodcutter, 1801-1863',
#  'Austrian association football player (1906-1956)',
#  '러시아-프랑스 화가',
#  'American painter (1923-1999)',
#  'Catholic bishop',
#  'Belgian historian, architect and noble',
#  'Spanish actress who won the Miss Universe 1974 pageant',
#  'American musician and pianist',
#  'Gambler, government official, politician and judge in Upper Canada',
#  'French psychiatrist',
#  'botanist (1912-1989)',
#  'cricketer (1878-1926)',
#  'Irish art dealer',
#  'Russian model',
#  'Canadian heart-lung transplant recipient',
#  'politician, died 1936',
#  'New Zealand rugby union player (1934-1987)',
#  'American cyclist',
#  'Argentine writer',
#  'British painter (1875-1952)',
#  'German architect (1896-1984)',
#  'painter of the Southern Netherlands',
#  'Australian headmaster and politician',
#  'American football player (1941-2018)',
#  'German mycologist (1821-1876)',
#  '1623 bis 1695 Geburtsort Hildesheim Sterbeort Hannover Konfession - Namensvarianten Hameln-Goldschmidt, Jente Hameln, Miriam Sara Jente Hameln-Goldschmidt, Jente Goldschmidt, Jendle Goldschmidt, Jente Goldschmidt, Jente Hameln- Goldschmidt, Jente Sar',
#  'American publisher',
#  'Swiss-American classical philologist (1926-2013)',
#  'Swedish schoolteacher and writer',
#  'uitgever uit Oostenrijk-Hongarije (1854-1914)',
#  'actor (1925-2009)',
#  'German entomologist',
#  'Soviet sculptor (1889-1953)',
#  'Australian rules footballer, born 1904',
#  'Holy Roman Empress',
#  'Polish politician',
#  'Welsh poet',
#  'Belgian sculptor and paintor (1868-1943) who moved to Brazil',
#  'Irish poet and schoolmaster',
#  'engraver and painter from the Northern Netherlands (1594-1683)',
#  'empresariu xaponés',
#  'English rugby league footballer',
#  'German actor (1904-1994)',
#  'NFL Team Owner',
#  'archaeologist',
#  'consultant paediatrician',
#  'American conspiracy theorist',
#  'Canadian businessman and politician',
#  'svensk akademiker',
#  'bushi',
#  'Polish musician',
#  'American journalist, historian and writer',
#  'American football player (1881-1965)',
#  'Norwegian-American structural engineer',
#  'Hero of the Soviet Union',
#  'English writer on military jurisprudence',
#  'British noble',
#  'Irish musicologist',
#  'Russian film director',
#  'chercheur français en intelligence artificielle',
#  '1882 bis 1927 Geburtsort Markirch (Sainte-Marie-aux-Mines, Elsaß) Sterbeort Aachen Beruf/Funktion Eisenhüttenkundler Konfession keine Angabe Namensvarianten Oberhoffer, Paul Oberhoffer, P.',
#  'Austrian-Dutch econometrician',
#  'American university teacher (1895-1968)',
#  'American director and production manager',
#  'Polish actress (1916-2006)',
#  'polski technolog żywności',
#  'Episcopal Bishop of Maryland',
#  'Connecticut politician',
#  'Japanese politician (1932-2000)',
#  'American scientist',
#  'toneelregisseur',
#  'US-amerikanischer Elektrotechniker',
#  'Danish psychologist (1910-1991)',
#  'Finnish textile artist',
#  'Czechoslovak minister of supply and Czechoslovak politician',
#  'Soviet partisan, journalist (1903-1942) and Heroine of the Soviet Union',
#  'Russian economist (1867-1933)',
#  'Australian palaeontologist',
#  'diplomaat uit Tsaardom Rusland',
#  'German engraver',
#  'actress (1888-1962)',
#  'aristocrate italienne',
#  'American activist',
#  'English lawyer',
#  'Anglican bishop',
#  'publisher, bookseller, print seller and librarian in Conwy',
#  'Stamp historian',
#  'scheidsrechter',
#  'American singer-songwriter',
#  'Egyptian journalist (1923-2016)',
#  'Docteur en médecine (Paris, 1934). - Prénoms complets : Maurice, Georges, Charles',
#  'Scottish footballer (1894-1946)',
#  'French catholic bishop',
#  '(1886-1956)',
#  'New Zealand nurse',
#  'German genealogist',
#  '(1902-1971)',
#  'Quigley, Janet Muriel Alexander (1902–1987), radio broadcaster',
#  'British soldier, politician, clergyman and author',
#  'American illustrator',
#  'Mexican politician, exponent of Mexican synarchism',
#  'former Irish Labour Party politician',
#  'British botanist (1768-1837)',
#  '(German, 1896–1956)',
#  'patholoog',
#  'American blues and rock vocalist; member of group Pacific Gas & Electric',
#  'Soviet dissident writer',
#  'Soviet botanist (1903-1984)',
#  'German botanist (1845–1897)',
#  'Spaans journalist (1874-1959)',
#  'French politician (1772-1847)',
#  'French gardener (1872-1948)',
#  'British parson',
#  'Church of England clergyman',
#  'British Member of Parliament (1676-1728)',
#  'Polish historian',
#  'finnischer Autor',
#  '1871-1951 , lawyer and legal reformer',
#  'Canadian-born businessman/bureaucrat',
#  'Dutch politician',
#  'Jerram, Charles (1770–1853), Church of England clergyman',
#  'Polish diplomat',
#  'Spanish abbot',
#  'born 1916; died 1974; VIAF 73919001',
#  'German Jewish lawyer, art dealer and art collector (1891-1978)',
#  'český evangelický farář',
#  'Italian footballer (1897-1943)',
#  'American actress (1972-2001)',
#  'French shipowner (1742-1811)',
#  'Austrian soldier (1711-1749)',
#  'French historian and Byzantinist',
#  'peruanischer Geschäftsmann und Bankier',
#  'Norwegian jurist',
#  'coleccionista español',
#  'Dutch nobleman (1650-1678)',
#  'Canadian swimmer, Olympic athlete, British Empire Games gold medallist',
#  'Frederick Augustus Franklin (1834-1909) 1909 Obituary &amp;#91;1&amp;#93; FREDERICK AUGUSTUS FRANKLIN died on his way to Australia on the 4th February, 1909, ...',
#  'German pharmacist',
#  'Dutch economist',
#  'Finnish poet, journalist and professor',
#  'سياسي أمريكي',
#  'Ceylon Tamil journalist',
#  'English association footballer (1911-1989)',
#  'priest, born 1734',
#  'Weihbischof in Köln',
#  'English Baroque architect',
#  'Song dynasty person CBDB = 7140',
#  'Latvian aircraft designer',
#  'Danish composer',
#  'pintor Hulandes',
#  'Swedish actor',
#  'politician (1515-1557)',
#  'Tanzanian politician and ambassador',
#  'historicus',
#  'German educationist and writer',
#  'German painter and xylographer',
#  'Follower of St. Francis of Assisi',
#  'Czechoslovak activist',
#  'German politician (CDU, SPD) (1912-1969)',
#  'Austrian military personnel',
#  '1727-04-11 - 1784-04-03',
#  'entomoloog',
#  'German archivist and historian',
#  'Spanish explorer (1569-1622)',
#  'Serbian chemist (1925-2014)',
#  'Studium in Leipzig; Ratsherr und Bürgermeister in Zittau; Jurist',
#  'Frans horlogemaker (1810-1889)',
#  'French politician and lawyer',
#  'Chilean politician',
#  'German jurist (1875–1955)',
#  'engraver from the Northern Netherlands',
#  'French chemist',
#  'Armerian armed militant',
#  'preußischer Generalmajor, Kommandant der Festung Cosel, Amtshauptmann von Zossen',
#  'Colombian film director',
#  'British Member of Parliament (1756-1785)',
#  'German anthropologist',
#  'English cricketer, born 1908',
#  'Argentinian musician and composer',
#  'espía español (1901–1954)',
#  'Frans vertaler (1765-1817)',
#  'German politician (1776-1871)',
#  'Weihbischof in Speyer, Karmelit',
#  'British Army officer',
#  'French jurist and politician',
#  'Swedish journalist',
#  'dansk filolog',
#  'Japanese actor and seiyū (1951-2020)',
#  'Belgian singer',
#  'estoński sportowiec',
#  'Lithuanian politician',
#  'American botanist (1816-1882)',
#  'English footballer (1913-1993)',
#  'Puerto Rican mayor',
#  'British doctor',
#  'horvát bán',
#  'Australian photographer',
#  'Austrian manufacturer (1812-1873)',
#  'Argentijns priester (1765-1824)',
#  'dansk skoleleder',
#  'German politician and member of landtag (1889-1970)',
#  'Polish sportsperson and ski jumper',
#  'Austrian professor',
#  'painter',
#  'English architect',
#  'American theatre director',
#  'politieagent',
#  'English footballer (1876-1949)',
#  '(1625-1625)',
#  'English cricketer (1894-1975)',
#  'politician (1875-1965)',
#  'Japanese psychologist',
#  'deutscher Lehrer, Gymnasialdirektor, Heimatforscher und Genealoge in Westpreußen',
#  'British painter (1866-1956)',
#  'English barrister, politician and author (1919-2006)',
#  'French monk',
#  'Dutch jurist',
#  'Choreographer and director',
#  'notaire, employé supérieur de ministère et receveur des finances français',
#  'German lithographer and author (1868-1957)',
#  '1619-1664; aus Straßburg; Jurist; Respondent an der Univ. Straßburg; Advokat am Reichskammergericht',
#  'French painter (1886-1965)',
#  'Scottish newspaper editor and author',
#  'Filipino writer',
#  'Italian entomologist (1821–1900)',
#  'equestrian',
#  'Croatian businessman',
#  'cartògraf, paborde de la catedral de Mallorca',
#  'British politician (1944-1995)',
#  'cricketer (1929-1997)',
#  'Сәвитләр Берлеге Каһарманы',
#  'politician, died 1847',
#  'herpetoloog',
#  'German diplomat',
#  'Puerto Rican musician, United States Army soldier',
#  'Ukrainian physician, public and political leader',
#  'Argentinian poet',
#  'grönländischer Landesrat',
#  'estoński informatyk',
#  'Hungarian architect (1873-1920)',
#  'Adjutant General of the U.S. Army from 1927 to 1928',
#  'French dramatist and novelist',
#  'French soldier',
#  'German violinist',
#  'British Baronet',
#  'Prince of Capua',
#  'chess player',
#  'wiskundige',
#  'Soviet politician',
#  'Dutch linguist and lecturer',
#  'polski inżynier, biomechanik',
#  'German architect and university teacher (1887-1948)',
#  'historiador e xornalista galego',
#  'German jurist and lawyer',
#  'Grand Princess consort, Byzantine noblewoman',
#  'English cricketer (1951-2010)',
#  'English cleric',
#  'German World War II U-boat commander',
#  'Canadian businessman',
#  'Intellectual and social activist',
#  'British cricketer (1931-1993)',
#  'British actress',
#  'Union Army general',
#  'Bulgarian politician',
#  'Ingeniero de Minas',
#  'American folklorist',
#  'French organist',
#  'French feminist economist',
#  'American businessman and philanthropist',
#  'American newspaper editor',
#  'Australian cricketer (1885-1965)',
#  'American baseball player, born 1973',
#  'American pathologist (1866-1943)',
#  'British archaeologist',
#  '(1794-1884) ügyvéd, színműíró',
#  '1885 - 1950, General surgeon and Physiologist',
#  'painter (1891-1976)',
#  'humorista gráficu brasilanu (1931–1994)',
#  'Soviet Russian geologist and geochemist',
#  'Egyptian poet',
#  'German politician (1904-1967)',
#  'Spaans officier (1723-1819)',
#  'German physician',
#  'Japanese naval aviator',
#  'French politician (1749-1841)',
#  'Polish poet',
#  'American surgeon',
#  'toneelacteur uit Koninkrijk Italië (1831-1898)',
#  'Recipient of the Cross of Valour',
#  'Swiss politician (1889-1970)',
#  'actor (1910-1953)',
#  'Canadian poet and novelist',
#  'English football player, senior career 1946-1955',
#  'Polish association football player (1949-1991)',
#  'Russian inventor',
#  'Hungarian genealogist and heraldist',
#  'Maltese electrician, engineer, and one of the first film actors',
#  'German art historian',
#  'British aristocrat',
#  ...]

# %%
# Create a dictionary of all possible values in the dataset and replace them with official country names.
country_mapping = {
    "Czechoslovakia": "Czech Republic",
    "nan": None,
    "Spain": "Spain",
    "Germany": "Germany",
    "United States of America": "United States",
    "Russia": "Russia",
    "Canada": "Canada",
    "Russian Empire": "Russia",
    "Switzerland": "Switzerland",
    "Norway": "Norway",
    "Kingdom of the Netherlands": "Netherlands",
    "Austria-Hungary": "Austria",
    "Egypt": "Egypt",
    "France": "France",
    "United Kingdom": "United Kingdom",
    "Belgium": "Belgium",
    "Argentina": "Argentina",
    "Kingdom of Great Britain": "United Kingdom",
    "Australia": "Australia",
    "Poland": "Poland",
    "Sweden": "Sweden",
    "Soviet Union": "Russia",
    "Bulgaria": "Bulgaria",
    "Japan": "Japan",
    "Wales": "United Kingdom",
    "United Kingdom of Great Britain and Ireland": "United Kingdom",
    "Luxembourg": "Luxembourg",
    "Austria": "Austria",
    "Estonia": "Estonia",
    "Brazil": "Brazil",
    "Finland": "Finland",
    "Kingdom of England": "United Kingdom",
    "Latvia": "Latvia",
    "Kingdom of Italy": "Italy",
    "India": "India",
    "New Zealand": "New Zealand",
    "Czech Republic": "Czech Republic",
    "Belarus": "Belarus",
    "Chile": "Chile",
    "Pakistan": "Pakistan",
    "Polish–Lithuanian Commonwealth": "Poland",
    "Denmark": "Denmark",
    "Scotland": "United Kingdom",
    "Hungary": "Hungary",
    "German Empire": "Germany",
    "Mexico": "Mexico",
    "Republic of Geneva": "Switzerland",
    "Italy": "Italy",
    "Netherlands": "Netherlands",
    "Republic of China (1912–1949)": "China",
    "Kingdom of Bavaria": "Germany",
    "Cossack Hetmanate": "Ukraine",
    "Nigeria": "Nigeria",
    "Papal States": "Vatican City",
    "England": "United Kingdom",
    "Ireland": "Ireland",
    "Yugoslavia": "Serbia",
    "Costa Rica": "Costa Rica",
    "South Korea": "South Korea",
    "South Africa": "South Africa",
    "Electorate of Saxony": "Germany",
    "Portugal": "Portugal",
    "Romania": "Romania",
    "Israel": "Israel",
    "Sri Lanka": "Sri Lanka",
    "Uruguay": "Uruguay",
    "Holy Roman Empire": "Germany",
    "People's Republic of China": "China",
    "Ghana": "Ghana",
    "Kingdom of Castile": "Spain",
    "ancient Rome": "Italy",
    "German Democratic Republic": "Germany",
    "Paraguay": "Paraguay",
    "Belize": "Belize",
    "Turkey": "Turkey",
    "Tsardom of Russia": "Russia",
    "Peru": "Peru",
    "Serbia": "Serbia",
    "Ottoman Empire": "Turkey",
    "Colombia": "Colombia",
    "Philippines": "Philippines",
    "Socialist Federal Republic of Yugoslavia": "Serbia",
    "Puerto Rico": "United States",
    "Byzantine Empire": "Turkey",
    "Republic of Venice": "Italy",
    "Malta": "Malta",
    "Kingdom of Sardinia": "Italy",
    "Ecuador": "Ecuador",
    "Croatia": "Croatia",
    "Kingdom of Württemberg": "Germany",
    "Cuba": "Cuba",
    "Dutch Republic": "Netherlands",
    "Kingdom of Scotland": "United Kingdom",
    "Lithuania": "Lithuania",
    "Tunisia": "Tunisia",
    "Eastern Han Dynasty": "China",
    "Greece": "Greece",
    "Montenegro": "Montenegro",
    "Austrian Empire": "Austria",
    "German Reich": "Germany",
    "Malaysia": "Malaysia",
    "Venezuela": "Venezuela",
    "Taiwan": "Taiwan",
    "Jamaica": "Jamaica",
    "Kingdom of Hungary": "Hungary",
    "Slovakia": "Slovakia",
    "Tanzania": "Tanzania",
    "Republic of Genova": "Italy",
    "China": "China",
    "Grenada": "Grenada",
    "Republic of Cyprus": "Cyprus",
    "Iran": "Iran",
    "Russian Soviet Federative Socialist Republic": "Russia",
    "Trinidad and Tobago": "Trinidad and Tobago",
    "Kyrgyzstan": "Kyrgyzstan",
    "Panama": "Panama",
    "Nauru": "Nauru",
    "Nazi Germany": "Germany",
    "Bolivia": "Bolivia",
    "North Korea": "North Korea",
    "Kingdom of Prussia": "Germany",
    "Afghanistan": "Afghanistan",
    "Spanish Empire": "Spain",
    "Sui dynasty": "China",
    "Joseon": "South Korea",
    "Angola": "Angola",
    "Indonesia": "Indonesia",
    "Algeria": "Algeria",
    "Crown of Aragón": "Spain",
    "Crown of Castile": "Spain",
    "Haiti": "Haiti",
    "Later Liang dynasty": "China",
    "Abbasid Caliphate": "Iraq",
    "Slovenia": "Slovenia",
    "Viceroyalty of New Spain": "Mexico",
    "Kingdom of Aragon": "Spain",
    "Archduchy of Austria": "Austria",
    "Duchy of Prussia": "Germany",
    "Prussia": "Germany",
    "Ukraine": "Ukraine",
    "Colony of New South Wales": "Australia",
    "Morocco": "Morocco",
    "Ming dynasty": "China",
    "Chechen Republic": "Russia",
    "British people": "United Kingdom",
    "Kingdom of Navarre": "Spain",
    "Lebanon": "Lebanon",
    "Vanuatu": "Vanuatu",
    "Umayyad Caliphate": "Spain",
    "Habsburg Netherlands": "Netherlands",
    "Duchy of Savoy": "Italy",
    "Song dynasty": "China",
    "El Salvador": "El Salvador",
    "Principality of Wallachia": "Romania",
    "Indians": "India",
    "Saxe-Weimar-Eisenach": "Germany",
    "Albania": "Albania",
    "Myanmar": "Myanmar",
    "Mozambique": "Mozambique",
    "Low Countries": "Netherlands",
    "Qing dynasty": "China",
    "Guatemala": "Guatemala",
    "Saar": "Germany",
    "Southern Netherlands": "Belgium",
    "Equatorial Guinea": "Equatorial Guinea",
    "Weimar Republic": "Germany",
    "Grand Duchy of Finland": "Finland",
    "Jordan": "Jordan",
    "Iceland": "Iceland",
    "Nicaragua": "Nicaragua",
    "Irish Free State": "Ireland",
    "Eswatini": "Eswatini",
    "Madagascar": "Madagascar",
    "Republic of Lucca": "Italy",
    "Grand Duchy of Tuscany": "Italy",
    "Kosovo": "Kosovo",
    "Dominican Republic": "Dominican Republic",
    "British Raj": "India",
    "Suriname": "Suriname",
    "Kingdom of France": "France",
    "San Marino": "San Marino",
    "Northern Zhou": "China",
    "Great Britain": "United Kingdom",
    "Iraq": "Iraq",
    "Republic of the Congo": "Republic of the Congo",
    "Duchy of Modena and Reggio": "Italy",
    "Democratic Republic of the Congo": "Democratic Republic of the Congo",
    "People's Republic of Poland": "Poland",
    "Liechtenstein": "Liechtenstein",
    "Burkina Faso": "Burkina Faso",
    "Uganda": "Uganda",
    "Sierra Leone": "Sierra Leone",
    "Brazilians": "Brazil",
    "Zimbabwe": "Zimbabwe",
    "Saint Kitts and Nevis": "Saint Kitts and Nevis",
    "Electorate of Hesse": "Germany",
    "Cape Verde": "Cape Verde",
    "São Tomé and Príncipe": "São Tomé and Príncipe",
    "British Hong Kong": "China",
    "Hong Kong": "China",
    "State of Palestine": "Palestine",
    "Provinces of India": "India",
    "Armenia": "Armenia",
    "British North America": "Canada",
    "Honduras": "Honduras",
    "Azerbaijan": "Azerbaijan",
    "Kingdom of Ireland": "Ireland",
    "Taifa of Granada": "Spain",
    "Tang Empire": "China",
    "Slovaks": "Slovakia",
    "People's Republic of Hungary": "Hungary",
    "Saudi Arabia": "Saudi Arabia",
    "Vietnam": "Vietnam",
    "Aztec Empire": "Mexico",
    "Electorate of Bavaria": "Germany",
    "Americans": "United States",
    "Barbados": "Barbados",
    "Kingdom of Bohemia": "Czech Republic",
    "Antigua": "Antigua and Barbuda",
    "Saxony": "Germany",
    "Viceroyalty of Perú": "Peru",
    "Habsburg Monarchy": "Austria",
    "Mughal Empire": "India",
    "Armenian Soviet Socialist Republic": "Armenia",
    "Benin": "Benin",
    "Gold Coast": "Ghana",
    "Bahamas": "Bahamas",
    "Byelorussian Soviet Socialist Republic": "Belarus",
    "Americana": "United States",
    "Northern Ireland": "United Kingdom",
    "Province of Canada": "Canada",
    "United Arab Emirates": "United Arab Emirates",
    "Zazzau": "Nigeria",
    "Georgia": "Georgia",
    "Liberia": "Liberia",
    "Jin dynasty": "China",
    "crown of Galicia": "Spain",
    "New France": "Canada",
    "Kingdom of Poland": "Poland",
    "Goryeo": "South Korea",
    "Oman": "Oman",
    "Cambodia": "Cambodia",
    "Bosnia and Herzegovina": "Bosnia and Herzegovina",
    "Kingdom of Saxony": "Germany",
    "Syria": "Syria",
    "Moldova": "Moldova",
    "Kazakhstan": "Kazakhstan",
    "Ivory Coast": "Ivory Coast",
    "Irish Republic": "Ireland",
    "Denmark-Norway": "Denmark",
    "Sierra Leone Colony and Protectorate": "Sierra Leone",
    "Kuwait": "Kuwait",
    "Kingdom of Yugoslavia": "Serbia",
    "Bermuda": "United Kingdom",
    "Western Han Dynasty": "China",
    "Kingdom of Naples": "Italy",
    "Yemen": "Yemen",
    "Togo": "Togo",
    "Nepal": "Nepal",
    "German Confederation": "Germany",
    "British Empire": "United Kingdom",
    "Kingdom of Hawaiʻi": "United States",
    "Kingdom of Portugal": "Portugal",
    "Kingdom of Tavolara": "Italy",
    "Uzbekistan": "Uzbekistan",
    "Duchy of Brabant": "Belgium",
    "Kingdom of Georgia": "Georgia",
    "Yuan dynasty": "China",
    "Spanish Netherlands": "Belgium",
    "Grand Duchy of Lithuania": "Lithuania",
    "Central African Republic": "Central African Republic",
    "Canada East": "Canada",
    "Canadians": "Canada",
    "Somalia": "Somalia",
    "Western Xia": "China",
    "Lordship of Bologna": "Italy",
    "Eritrea": "Eritrea",
    "Fiji": "Fiji",
    "Qutb Shahi dynasty": "India",
    "Kingdom of Asturias": "Spain",
    "Italians": "Italy",
    "County of Champagne": "France",
    "Kingdom of Iraq": "Iraq",
    "Republic of Florence": "Italy",
    "Faroe Islands": "Denmark",
    "Flintshire": "United Kingdom",
    "Kingdom of Denmark": "Denmark",
    "East Timor": "East Timor",
    "New South Wales": "Australia",
    "Rwanda": "Rwanda",
    "Thebes": "Greece",
    "Gabon": "Gabon",
    "Jersey": "United Kingdom",
    "Duchy of Luxembourg": "Luxembourg",
    "Confederation of the Rhine": "Germany",
    "Kenya": "Kenya",
    "Ancient Egypt": "Egypt",
    "English people": "United Kingdom",
    "Colonial Brazil": "Brazil",
    "North Macedonia": "North Macedonia",
    "Southern Qi": "China",
    "Northern Wei": "China",
    "Guyana": "Guyana",
    "Tuvalu": "Tuvalu",
    "Cameroon": "Cameroon",
    "Dominica": "Dominica",
    "Ryukyu Kingdom": "Japan",
    "Emirate of Granada": "Spain",
    "Safavid dynasty": "Iran",
    "Libya": "Libya",
    "Bohemia": "Czech Republic",
    "Zambia": "Zambia",
    "Antigua and Barbuda": "Antigua and Barbuda",
    "United States Virgin Islands": "United States",
    "Namibia": "Namibia",
    "Safavid Empire": "Iran",
    "Senegal": "Senegal",
    "Macedonia": "North Macedonia",
    "Mali": "Mali",
    "Mandatory Palestine": "Israel",
    "Kyivska Rus'": "Ukraine",
    "Española": "Dominican Republic",
    "County of Savoy": "Italy",
    "Kingdom of Pamplona": "Spain",
    "Cao Wei": "China",
    "Northern Netherlands": "Netherlands",
    "Northern Song Dynasty": "China",
    "Louisiana": "United States",
    "Duchy of Württemberg": "Germany",
    "County of Flanders": "Belgium",
    "Former Shu": "China",
    "Papua New Guinea": "Papua New Guinea",
    "Cook Islands Māori people": "Cook Islands",
    "Province of Quebec": "Canada",
    "Kingdom of Mysore": "India",
    "emirate of Córdoba": "Spain",
    "Arabian Peninsula": None,
    "Mauritania": "Mauritania",
    "Gambia": "Gambia",
    "Kingdom of Burgundy": "France",
    "Later Han dynasty": "China",
    "Serbian Grand Principality": "Serbia",
    "British Guiana": "Guyana",
    "Principality of Moldavia": "Moldova",
    "Grand Duchy of Hesse": "Germany",
    "Second Polish Republic": "Poland",
    "Duchy of Parma": "Italy",
    "Prince-Bishopric of Liège": "Belgium",
    "Australians": "Australia",
    "Oudh State": "India",
    "Kingdom of Leinster": "Ireland",
    "Sudan": "Sudan",
    "Kingdom of the Two Sicilies": "Italy",
    "Kingdom of Dyfed": "United Kingdom",
    "Burundi": "Burundi",
    "London": "United Kingdom",
    "Niger": "Niger",
    "Niue": "Niue",
    "Durrani Empire": "Afghanistan",
    "Volhynia": "Ukraine",
    "Frankfurt": "Germany",
    "Cape Colony": "South Africa",
    "Transylvania": "Romania",
    "Mauritius": "Mauritius",
    "South Sudan": "South Sudan",
    "French Madagascar": "Madagascar",
    "Lower Canada": "Canada",
    "French Second Republic": "France",
    "Brandenburg-Prussia": "Germany",
    "Kingdom of León": "Spain",
    "Duchy of Bohemia": "Czech Republic",
    "Gujarat Sultanate": "India",
    "Kingdom of Serbia": "Serbia",
    "Singapore": "Singapore",
    "Province of Bologna": "Italy",
    "Republic of Siena": "Italy",
    "West Germany": "Germany",
    "Nyasaland": "Malawi",
    "Bavaria": "Germany",
    "Kingdom of Romania": "Romania",
    "Visigothic Spain": "Spain",
    "Liao dynasty": "China",
    "Electorate of Mainz": "Germany",
    "Kingdom of Hanover": "Germany",
    "Viceroyalty of the Río de la Plata": "Argentina",
    "Botswana": "Botswana",
    "Korean Empire": "South Korea",
    "Qi": "China",
    "Grand Duchy of Vladimir": "Russia",
    "Chad": "Chad",
    "Samoa": "Samoa",
    "Sheikhdom of Kuwait": "Kuwait",
    "Duchy of Florence": "Italy",
    "Sultanate of Siak Sri Indrapura": "Indonesia",
    "Seleucid Empire": None,
    "Chen dynasty": "China",
    "Duchy of Milan": "Italy",
    "Dominion of New Zealand": "New Zealand",
    "Great Seljuq Empire": None,
    "Republic of Texas": "United States",
    "Kingdom of Kakheti": "Georgia",
    "Spanish Guinea": "Equatorial Guinea",
    "Arabs": None,
    "Al-Andalus": "Spain",
    "Brunei": "Brunei",
    "Palestine": "Palestine",
    "Principality of Ryazan": "Russia",
    "Flanders": "Belgium",
    "Colony of Virginia": "United States",
    "French First Republic": "France",
    "Belgians": "Belgium",
    "British America": "United States",
    "Serbian Despotate": "Serbia",
    "Duchy of Urbino": "Italy",
    "Duchy of Brunswick": "Germany",
    "Isle of Man": "United Kingdom",
    "Kingdom of Mercia": "United Kingdom",
    "Kingdom of Galicia": "Spain",
    "Transnistria": "Moldova",
    "Colony of New Zealand": "New Zealand",
    "Union between Sweden and Norway": "Sweden",
    "Kingdom of Galicia and Lodomeria": "Poland",
    "Gourdon": "France",
    "Kingdom of Sicily": "Italy",
    "United Arab Republic": "Egypt",
    "Kingdom of Kongo": "Angola",
    "Kingdom of Kartli": "Georgia",
    "Canton of Solothurn": "Switzerland",
    "Awadh": "India",
    "Aruba": "Netherlands",
    "Maldives": "Maldives",
    "Thailand": "Thailand",
    "Qin": "China",
    "Principality of Montenegro": "Montenegro",
    "Cardiff": "United Kingdom",
    "Venice": "Italy",
    "Kingdom of Aksum": "Ethiopia",
    "Guinea": "Guinea",
    "Almoravid dynasty": "Morocco",
    "Kingdom of Cyprus": "Cyprus",
    "Mamluk Sultanate": "Egypt",
    "Taifa of Dénia": "Spain",
    "Greenland": "Denmark",
    "Turkish Republic of Northern Cyprus": "Cyprus",
    "Germans": "Germany",
    "Kingdom of Lombardy–Venetia": "Italy",
    "Bremen": "Germany",
    "Grand Duchy of Oldenburg": "Germany",
    "Carthage": "Tunisia",
    "Burgundian Netherlands": "Netherlands",
    "Liu Song dynasty": "China",
    "Republic of Ragusa": "Croatia",
    "Novgorod Republic": "Russia",
    "Saint Lucia": "Saint Lucia",
    "Principality of Serbia": "Serbia",
    "State of the Teutonic Order": "Poland",
    "Duchy of Mirandola": "Italy",
    "fictional extraterrestrial": None,
    "Seychelles": "Seychelles",
    "Uyghur": "China",
    "Empire of Japan": "Japan",
    "Lakota people": "United States",
    "Mallorquina": "Spain",
    "Turkmenistan": "Turkmenistan",
    "Lesotho": "Lesotho",
    "Andorra": "Andorra",
    "Margraviate of Baden-Durlach": "Germany",
    "Achaemenid Empire": "Iran",
    "Southern Song Dynasty": "China",
    "County of Barcelona": "Spain",
    "Kingdom of Valencia": "Spain",
    "Taiping Heavenly Kingdom": "China",
    "Champa": "Vietnam",
    "Ukrainian Soviet Socialist Republic": "Ukraine",
    "Ptolemaic Kingdom": "Egypt",
    "Serbian Empire": "Serbia",
    "United Principalities": "Romania",
    "American Samoa": "United States",
    "Kingdom of Abkhazia": "Georgia",
    "Kiribati": "Kiribati",
    "Captaincy General of the Philippines": "Philippines",
    "Duchy of Bavaria": "Germany",
    "Union of South Africa": "South Africa",
    "Kingdom of Toledo": "Spain",
    "Paris": "France",
    "Grand Duchy of Mecklenburg-Schwerin": "Germany",
    "Slovak State (1939-1945)": "Slovakia",
    "Han dynasty": "China",
    "Chu": "China",
    "Austrian Netherlands": "Belgium",
    "Austrians": "Austria",
    "Baden": "Germany",
    "Grand Duchy of Moscow": "Russia",
    "Ukrainian State": "Ukraine",
    "Later Tang Dynasty": "China",
    "Malawi": "Malawi",
    "Dalmatia": "Croatia",
    "Dutch people": "Netherlands",
    "Emirate of Afghanistan": "Afghanistan",
    "Duchy of Lucca": "Italy",
    "Mongolia": "Mongolia",
    "Western Wei": "China",
    "Grand Duchy of Baden": "Germany",
    "Duchy of Mantua": "Italy",
    "Electoral Palatinate": "Germany",
    "Giudicato of Arborea": "Italy",
    "Estados Unidos": "United States",
    "Ethiopia": "Ethiopia",
    "Portuguese Empire": "Portugal",
    "Later Shu": "China",
    "Duchy of Ferrara": "Italy",
    "Classical Athens": "Greece",
    "Crown of the Kingdom of Poland": "Poland",
    "Djibouti": "Djibouti",
    "Hyderabad State": "India",
    "July Monarchy": "France",
    "Saint Vincent and the Grenadines": "Saint Vincent and the Grenadines",
    "Qajar dynasty": "Iran",
    "Republic of Mainz": "Germany",
    "Visigoths": "Spain",
    "Hamburg": "Germany",
    "Carolingian Empire": "France",
    "Italian Social Republic": "Italy",
    "Dutch East Indies": "Indonesia",
    "French Third Republic": "France",
    "Federal Republic of Central America": "Guatemala",
    "Principality of Catalonia": "Spain",
    "Qin dynasty": "China",
    "Caliphate of Córdoba": "Spain",
    "Federated States of Micronesia": "Federated States of Micronesia",
    "Kingdom of Naples and Sicily": "Italy",
    "French people": "France",
    "Montserrat": "United Kingdom",
    "Kingdom of Gwynedd": "United Kingdom",
    "Swedish Empire": "Sweden",
    "Sweden-Finland": "Sweden",
    "Monaco": "Monaco",
    "México": "Mexico",
    "Holy See": "Vatican City",
    "Captaincy General of Guatemala": "Guatemala",
    "Later Yan": "China",
    "Francia": "France",
    "Western Sahara": "Western Sahara",
    "history of Genoa": "Italy",
    "Kingdom of Imereti": "Georgia",
    "First French Empire": "France",
    "North Vietnam": "Vietnam",
    "Electorate of Brunswick-Lüneburg": "Germany",
    "West Francia": "France",
    "Welsh people": "United Kingdom",
    "Kingdom of Majorca": "Spain",
    "Moravian Serbia": "Serbia",
    "Confederate States of America": "United States",
    "Netherlands Antilles": "Netherlands",
    "Portuguese Cape Verde": "Cape Verde",
    "Portuguese Guinea": "Guinea-Bissau",
    "First Bulgarian Empire": "Bulgaria",
    "Duchy of Brittany": "France",
    "Asia": None,
    "County of Conflent": "Spain",
    "Venezolano": "Venezuela",
    "Kingdom of Matamba": "Angola",
    "Kingdom of Bosnia": "Bosnia and Herzegovina",
    "Egypt Eyalet": "Egypt",
    "Saint-Domingue": "Haiti",
    "Principality of Antioch": "Syria",
    "Empire of Nicaea": "Turkey",
    "Vatican City": "Vatican City",
    "Frances": "France",
    "Saxe-Gotha-Altenburg": "Germany",
    "Tonga": "Tonga",
    "Piedmont": "Italy",
    "Spanish East Indies": "Philippines",
    "Principality of Bulgaria": "Bulgaria",
    "Cisalpine Republic": "Italy",
    "Spanish": "Spain",
    "Duchy of Brunswick-Lüneburg": "Germany",
    "Wuyue": "China",
    "Imperial State of Iran": "Iran",
    "Sparta": "Greece",
    "United Kingdom of the Netherlands": "Netherlands",
    "Kingdom of Jerusalem": "Israel",
    "Silla": "South Korea",
    "Congo Free State": "Democratic Republic of the Congo",
    "Galicia": "Spain",
    "Guernsey": "United Kingdom",
    "Rashidun Caliphates": None,
    "Palau": "Palau",
    "Margraviate of Brandenburg": "Germany",
    "Kingdom of Northumbria": "United Kingdom",
    "Guinea-Bissau": "Guinea-Bissau",
    "State of Brazil": "Brazil",
    "Verona": "Italy",
    "Upper Canada": "Canada",
    "Duchy of Austria": "Austria",
    "Quebec": "Canada",
    "Bahrain": "Bahrain",
    "Duchy of Lorraine": "France",
    "Rhodesia": "Zimbabwe",
    "Kingdom of Wessex": "United Kingdom",
    "North German Confederation": "Germany",
    "Western Jin dynasty": "China",
    "Normandy": "France",
    "People's Republic of Bulgaria": "Bulgaria",
    "Bhutan": "Bhutan",
    "Visigothic Kingdom": "Spain",
    "Cook Islands": "Cook Islands",
    "Italian Empire": "Italy",
    "Eastern Wu": "China",
    "Batavian Republic": "Netherlands",
    "Kingdom of Hungary in the Middle Ages": "Hungary",
    "Congress Poland": "Poland",
    "Austrasia": "France",
    "Kingdom of Spain": "Spain",
    "Hungarian": "Hungary",
    "Romanian": "Romania",
    "Northern Qi": "China",
    "Hesse": "Germany",
    "Wallachia": "Romania",
    "Duke of Holstein-Gottorp": "Germany",
    "Anhalt-Bernburg": "Germany",
    "Uruguaya": "Uruguay",
    "County of Burgundy": "France",
    "Goguryeo": "North Korea",
    "Duchy of Schleswig": "Denmark",
    "duchy of Saxe-Coburg and Gotha": "Germany",
    "Lu": "China",
    "Anjou": "France",
    "Epirus": "Greece",
    "Serbia and Montenegro": "Serbia",
    "Swabia": "Germany",
    "Eastern Jin dynasty": "China",
    "Australasia": "Australia",
    "Shang dynasty": "China",
    "Kingdom of Hejaz": "Saudi Arabia",
    "County of Württemberg": "Germany",
    "Cutch State": "India",
    "Bangladesh": "Bangladesh",
    "Artsakh": "Azerbaijan",
    "Tibet": "China",
    "Canadian nationality law": "Canada",
    "statelessness": None,
    "Tajikistan": "Tajikistan",
    "Socialist Republic of Romania": "Romania",
    "Marinid dynasty": "Morocco",
    "Principality of Transylvania": "Romania",
    "Cheng Han": "China",
    "County of Holland": "Netherlands",
    "Southern Han": "China",
    "Hanau-Münzenberg": "Germany",
    "Shu Han": "China",
    "Lübeck": "Germany",
    "Ayyubid dynasty": "Egypt",
    "Kingdom of Rheged": "United Kingdom",
    "Rus' people": "Ukraine",
    "Iowa": "United States",
    "British": "United Kingdom",
    "Second Spanish Republic": "Spain",
    "Marshall Islands": "Marshall Islands",
    "Bologna": "Italy",
    "Kingdom of Bulgaria": "Bulgaria",
    "Milan": "Italy",
    "Liang dynasty": "China",
    "Palestinian National Authority": "Palestine",
    "Captaincy General of Cuba": "Cuba",
    "Spaniards": "Spain",
    "Venezuelans": "Venezuela",
    "Castile": "Spain",
    "Kingdom of Iberia": "Georgia",
    "Min": "China",
    "Siberian": "Russia",
    "Newfoundland": "Canada",
    "Livonia": "Latvia",
    "Ottoman Syria": "Syria",
    "Kingdom of the Lombards": "Italy",
    "Principality of Lippe": "Germany",
    "Margraviate of Baden-Baden": "Germany",
    "Gupta Empire": "India",
    "Curaçao": "Netherlands",
    "Great Moravia": "Czech Republic",
    "Canada–United States border": "United States",
    "Duchy of Saxony": "Germany",
    "Taifa of Zaragoza": "Spain",
    "Qatar": "Qatar",
    "Fatimid caliphate": "Egypt",
    "Duchy of Naples": "Italy",
    "Ag Qoyunlu Tribe": "Iran",
    "Schwarzburg-Sondershausen": "Germany",
    "Ghaznavid Empire": "Afghanistan",
    "Xin dynasty": "China",
    "Kongo people": "Angola",
    "Hindustan": "India",
    "French": "France",
    "Bishopric of Trent": "Italy",
    "Lordship of Ireland": "Ireland",
    "Republic of Pisa": "Italy",
    "Later Zhou dynasty": "China",
    "Kingdom of Munster": "Ireland",
    "Florencia": "Colombia",
    "Abbasids": "Iraq",
    "Kingdom of Croatia": "Croatia",
    "Qajar Iran": "Iran",
    "Polona": "Poland",
    "County of Roussillon": "France",
    "Manchukuo": "China",
    "Gibraltar": "United Kingdom",
    "Province of Massachusetts Bay": "United States",
    "Landgraviate of Hesse": "Germany",
    "Dál Riata": "United Kingdom",
    "Roman Catholic Archdiocese of Warmia": "Poland",
    "Kition": "Cyprus",
    "Republic of New Granada": "Colombia",
    "Saxe-Zeitz": "Germany",
    "Later Zhao": "China",
    "United States of the Ionian Islands": "Greece",
    "Ruanda-Urundi": "Rwanda",
    "Princes of Paliano": "Italy",
    "Duchy of Burgundy": "France",
    "Bactria": "Afghanistan",
    "Septinsular Republic": "Greece",
    "Janina Vilayet": "Greece",
    "Sokoto Caliphate": "Nigeria",
    "Württemberg": "Germany",
    "Wu": "China",
    "Hesse-Homburg": "Germany",
    "British West Indies": "Bahamas",
    "Duchy of Nassau": "Germany",
    "Bergamo": "Italy",
    "Jingnan": "China",
    "Kingdom of Croatia-Slavonia": "Croatia",
    "Seventeen Provinces": "Netherlands",
    "Emirate of Diriyah": "Saudi Arabia",
    "Ukrainians": "Ukraine",
    "Mexicans": "Mexico",
    "Ashanti Empire": "Ghana",
    "Tabaristan": "Iran",
    "British Overseas Territories": "United Kingdom",
    "Yemen Arab Republic": "Yemen",
    "Malta Colony": "Malta",
    "Ho Chi Minh City": "Vietnam",
    "Korea": "South Korea",
    "Turkish": "Turkey",
    "Guatemalteca": "Guatemala",
    "Chagatai Khanate": "Uzbekistan",
    "Duchy of Mecklenburg-Schwerin": "Germany",
    "Domnonée": "France",
    "Duchy of Holstein": "Germany",
    "Lâm Ấp": "Vietnam",
    "Helvetic Republic": "Switzerland",
    "United States of Colombia": "Colombia",
    "Duchy of Castro": "Italy",
    "French Indochina": "Vietnam",
    "Serbian": "Serbia",
    "Inner Mongolia": "China",
    "Margraviate of Moravia": "Czech Republic",
    "Mongol Empire": "Mongolia",
    "New York": "United States",
    "Mutawakkilite Kingdom of Yemen": "Yemen",
    "Laos": "Laos",
    "Timurid Empire": "Uzbekistan",
    "Giudicato of Cagliari": "Italy",
    "Francesa": "France",
    "West Ukrainian People's Republic": "Ukraine",
    "Duchy of Normandy": "France",
    "Cisleithania": "Austria",
    "Kingdom of Pontus": "Turkey",
    "Rome": "Italy",
    "Zanzibar North Region": "Tanzania",
    "island nation": None,
    "Kingdom of Makuria": "Sudan",
    "South Vietnam": "Vietnam",
    "Cherokee Nation": "United States",
    "Second Bulgarian Empire": "Bulgaria",
    "German": "Germany",
    "Empire of Brazil": "Brazil",
    "composer": None,
    "Taiwan under Japanese rule": "Taiwan",
    "Georgian Soviet Socialist Republic": "Georgia",
    "ducat de Bremen": "Germany",
    "Peruana": "Peru",
    "Armenian Kingdom of Cilicia": "Armenia",
    "Mazatlán": "Mexico",
    "historical country": None,
    "Bruneian Empire": "Brunei",
    "Kingdom of Holland": "Netherlands",
    "South African Republic": "South Africa",
    "España": "Spain",
    "Kingdom of Greece": "Greece",
    "Period of appanages": "Russia",
    "United Provinces of the Río de la Plata": "Argentina",
    "Toucouleur Empire": "Senegal",
    "Eretnids": "Turkey",
    "County of Sicily": "Italy",
    "Phlius": "Greece",
    "Principality of Beloozero": "Russia",
    "Brandenburg": "Germany",
    "Bijapur Sultanate": "India",
    "The Colony known as The Bay of Massachusetts": "United States",
    "Mewar": "India",
    "New Guinea": "Papua New Guinea",
    "Judah": "Israel",
    "Ukrainian People's Republic": "Ukraine",
    "Upper Peru": "Bolivia",
    "Silesia": "Poland",
    "Eastern Wei": "China",
    "Umayyad dynasty": "Spain",
    "Southern Tang": "China",
    "Zhao": "China",
    "Australasia at the Olympics": "Australia",
    "Judea": "Israel",
    "Kingdom of Armenia": "Armenia",
    "North Sea Empire": "Denmark",
    "Southern Rhodesia": "Zimbabwe",
    "Solomon Islands": "Solomon Islands",
    "Surinam": "Suriname",
    "Taifa of Almería": "Spain",
    "Holland": "Netherlands",
    "Republic of San Marco": "Italy",
    "Delhi Sultanate": "India",
    "County of Apulia and Calabria": "Italy",
    "Baghdad": "Iraq",
    "Chileans": "Chile",
    "Bosporan Kingdom": "Russia",
    "Captaincy General of Puerto Rico": "Puerto Rico",
    "Neptuno": None,
    "Hol": "Netherlands",
    "British Honduras": "Belize",
    "Azerbaijan Soviet Socialist Republic": "Azerbaijan",
    "Empire of China": "China",
    "Wallis": "Wallis and Futuna",
    "Almohad Caliphate": "Morocco",
    "Grand Duchy of Mecklenburg-Strelitz": "Germany",
    "Government of National Unity": "South Africa",
    "Travancore": "India",
    "Signoria of Milan": "Italy",
    "Saxe-Gotha": "Germany",
    "Indigenous peoples of America": None,
    "canton of Basel": "Switzerland",
    "Colombiana": "Colombia",
    "Sui": "China",
    "Togoland": "Togo",
    "Zengid dynasty": "Syria",
    "Thrace": "Turkey",
    "Shahrisabz": "Uzbekistan",
    "Argentino": "Argentina",
    "Thirteen Colonies": "United States",
    "Kenya Colony": "Kenya",
    "Polish–Lithuanian union": "Poland",
    "Korea under Japanese rule": "South Korea",
    "Hawaii": "United States",
    "County of Aragon": "Spain",
    "Rouen": "France",
    "Belarusian People's Republic": "Belarus",
    "Austro-Hungarian rule in Bosnia and Herzegovina": "Bosnia and Herzegovina",
    "Merthyr Tydfil County Borough": "United Kingdom",
    "Free City of Frankfurt": "Germany",
    "Peruano": "Peru",
    "Principality of Abkhazia": "Georgia",
    "nationality": None,
    "Britannia": "United Kingdom",
    "Kurdistan": None,
    "French protectorate of Tunisia": "Tunisia",
    "Landgraviate of Hesse-Kassel": "Germany",
    "Portuguese India": "India",
    "Canadian English": "Canada",
    "Schleswig-Holstein": "Germany",
    "Landgraviate of Hesse-Darmstadt": "Germany",
    "Commonwealth of the Philippines": "Philippines",
    "Emirate of Sicily": "Italy",
    "Rascia": "Serbia",
    "Golden Horde": "Russia",
    "South Tyrol": "Italy",
    "Kingdom of Candia": "Greece",
    "Danish West Indies": "United States",
    "Allemang": "Germany",
    "Sub-Roman Britain": "United Kingdom",
    "Spanish": "Spain",
    "German": "Germany",
    "Canadian": "Canada",
    "Russian": "Russia",
    "Norwegian": "Norway",
    "Dutch": "Netherlands",
    "Dominican": "Dominican Republic",
    "Swiss": "Switzerland",
    "American": "United States",
    "Finnish": "Finland",
    "French": "France",
    "British": "United Kingdom",
    "Belgian": "Belgium",
    "President of Argentina": "Argentina",
    "New Zealand": "New Zealand",
    "Basque": "Spain",
    "English": "United Kingdom",
    "Polish": "Poland",
    "Italian": "Italy",
    "Swedish": "Sweden",
    "Japanese": "Japan",
    "Ukrainian": "Ukraine",
    "Scottish": "United Kingdom",
    "Australian": "Australia",
    "Soviet": "Russia",
    "Czech": "Czech Republic",
    "Irish": "Ireland",
    "Turkish": "Turkey",
    "Brazilian": "Brazil",
    "Austrian": "Austria",
    "Hungarian": "Hungary",
    "Indian": "India",
    "Urdu": "Pakistan",
    "African-American": "United States",
    "Puerto Rican": "United States",
    "Northern Irish": "United Kingdom",
    "Hawaiian": "United States",
    "South African": "South Africa",
    "Slovene": "Slovenia",
    "Costa Rican": "Costa Rica",
    "Estonian": "Estonia",
    "Lithuanian": "Lithuania",
    "Mexican": "Mexico",
    "South Korean": "South Korea",
    "Paraguayan": "Paraguay",
    "Sri Lankan": "Sri Lanka",
    "Argentinian": "Argentina",
    "Cameroonian": "Cameroon",
    "Armenian": "Armenia",
    "Ghanaian": "Ghana",
    "Romanian": "Romania",
    "Iraqi-Canadian": "Canada",
    "Saudi Arabian": "Saudi Arabia",
    "Mauritian": "Mauritius",
    "Ceylon Tamil": "Sri Lanka",
    "Tanzanian": "Tanzania",
    "Serbian": "Serbia",
    "Colombian": "Colombia",
    "Filipino": "Philippines",
    "Croatian": "Croatia",
    "Portuguese": "Portugal",
    "Chilean": "Chile",
    "Latvian": "Latvia",
}

# %%
df_2['Country_cleaned'] = df_2['Country'].map(country_mapping).fillna(df_2['Country'])

# %%
df_2
# Out:
#                          Name  Gender         Country  Birth year  Death year  \
# 0                   Yin Buhai     NaN    Chen dynasty         505       589.0
# 1          Johann von Wickede     1.0             NaN        1664      1732.0
# 2             Frank McCashney     1.0       Australia        1890      1951.0
# 3                Hugo Berwald     1.0         Germany        1863      1937.0
# 4                 Karel Fiala     1.0  Czechoslovakia        1871      1931.0
# ...                       ...     ...             ...         ...         ...
# 855984        Foster Andersen     1.0             NaN        1940      2004.0
# 855985     Mieczysław Warmski     1.0          Poland        1855      1916.0
# 855986  Gustav Adolf Goldberg     1.0         Germany        1848      1911.0
# 855987       Reinaldo Giudici     1.0       Argentina        1853      1921.0
# 855988          Gaston Briese     1.0         Germany        1898      1953.0
#
#        Manner of death Country_cleaned
# 0                  NaN           China
# 1                  NaN             NaN
# 2                  NaN       Australia
# 3                  NaN         Germany
# 4                  NaN  Czech Republic
# ...                ...             ...
# 855984             NaN             NaN
# 855985             NaN          Poland
# 855986             NaN         Germany
# 855987             NaN       Argentina
# 855988             NaN         Germany
#
# [855989 rows x 7 columns]

# %% [markdown]
# matching two datasets

# %%
df_matched=df_1.merge(df_2,left_on='Name',right_on='Name',how='inner')

# %%
df_matched.drop(columns=['Country', 'Manner of death'],inplace=True)

# %%
#rename cleaned coulmn
df_matched.rename(columns={'Country_cleaned':'Country'},inplace=True)

# %%
df_matched.head(15)
# Out:
#                                 Name              Short description Gender_x  \
# 0                     Vilém Pospíšil               Baptist minister     Male
# 1                     Vilém Pospíšil               Baptist minister     Male
# 2                    Elise Schmieden        schrijfster (1841-1896)      NaN
# 3                  Jerónimo de Rueda        Spanish baroque painter     Male
# 4   August Karl Wilhelm Weissenbruch                  German author     Male
# 5                  William Abbenseth                   photographer     Male
# 6                    Anatoly Krupnov  musician and poet (1965-1997)     Male
# 7                    Wilhelm Denhard              German politician     Male
# 8                    Wilhelm Denhard              German politician     Male
# 9              Francis Edwin Kilvert            Canadian politician     Male
# 10                           Ilarion                 Russian priest      NaN
# 11                   Johannes Müller                  German jurist     Male
# 12                   Johannes Müller                  German jurist     Male
# 13                   Johannes Müller                  German jurist     Male
# 14                   Johannes Müller                  German jurist     Male
#
#           Occupation  Age of death Gender_y  Birth year  Death year  \
# 0             Pastor          73.0      1.0        1873      1942.0
# 1             Pastor          73.0      1.0        1910      1976.0
# 2             Artist          55.0  Unknown        1841      1896.0
# 3             Artist          80.0      1.0        1670      1750.0
# 4             Artist          82.0      1.0        1744      1826.0
# 5             Artist          74.0      1.0        1898      1972.0
# 6             Artist          32.0      1.0        1965      1997.0
# 7         Politician          72.0      1.0        1807      1879.0
# 8         Politician          72.0      1.0        1876      1944.0
# 9         Politician          72.0      1.0        1838      1910.0
# 10  Religious figure          75.0  Unknown        1776      1851.0
# 11            Jurist          43.0      1.0        1861      1920.0
# 12            Jurist          43.0      1.0        1847      1907.0
# 13            Jurist          43.0      1.0        1935      2012.0
# 14            Jurist          43.0      1.0        1887      2000.0
#
#            Country
# 0   Czech Republic
# 1              NaN
# 2              NaN
# 3            Spain
# 4          Germany
# 5    United States
# 6           Russia
# 7          Germany
# 8          Germany
# 9           Canada
# 10          Russia
# 11             NaN
# 12         Germany
# 13         Germany
# 14         Germany

# %%
df_matched[['Gender_x','Gender_y']].isna().sum()
# Out:
# Gender_x    94285
# Gender_y    93871
# dtype: int64

# %%
#filling massing value in Gender
df_matched['Gender_y'].fillna('Unknown', inplace=True)
# Out:
# <ipython-input-145-7548e58989dc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matched['Gender_y'].fillna('Unknown', inplace=True)

# %%
#change format of values
df_matched['Gender_y'].replace({1: 'Male', 2: 'Female'}, inplace=True)

# %% [markdown]
# #Check Data consistancy

# %%
check_age =df_matched['Death year'] - df_matched['Birth year']
# Out:
# 0         69.0
# 1         66.0
# 2         55.0
# 3         80.0
# 4         82.0
#           ...
# 927600    54.0
# 927601    56.0
# 927602    72.0
# 927603    75.0
# 927604    37.0
# Length: 927605, dtype: float64

# %%
# The 'Age of Death' column is not consistent.
(df_matched['Age of death']== check_age).all()
# Out:
# np.False_

# %%
(df_matched['Age of death']!= check_age).sum()
# Out:
# np.int64(279311)

# %%
df_matched['Age'] =df_matched['Death year'] - df_matched['Birth year']

# %%
df_matched
# Out:
#                                     Name                   Short description  \
# 0                         Vilém Pospíšil                    Baptist minister
# 1                         Vilém Pospíšil                    Baptist minister
# 2                        Elise Schmieden             schrijfster (1841-1896)
# 3                      Jerónimo de Rueda             Spanish baroque painter
# 4       August Karl Wilhelm Weissenbruch                       German author
# ...                                  ...                                 ...
# 927600                       Hans Bosman                       Dutch painter
# 927601            Philip Jones of Fonmon                    Welsh politician
# 927602                Stefan Jakovljević                botanist (1890-1962)
# 927603                     Kurt Berthold  maestru d'armes alemán (1902–1977)
# 927604                    Zygmunt Mitera                     polnischer Arzt
#
#        Gender_x  Occupation  Age of death Gender_y  Birth year  Death year  \
# 0          Male      Pastor          73.0     Male        1873      1942.0
# 1          Male      Pastor          73.0     Male        1910      1976.0
# 2           NaN      Artist          55.0  Unknown        1841      1896.0
# 3          Male      Artist          80.0     Male        1670      1750.0
# 4          Male      Artist          82.0     Male        1744      1826.0
# ...         ...         ...           ...      ...         ...         ...
# 927600     Male      Artist          54.0     Male        1958      2012.0
# 927601     Male  Politician          56.0     Male        1618      1674.0
# 927602     Male  Researcher          72.0     Male        1890      1962.0
# 927603     Male     Athlete          75.0     Male        1902      1977.0
# 927604     Male   Physician          37.0     Male        1903      1940.0
#
#                Country   Age
# 0       Czech Republic  69.0
# 1                  NaN  66.0
# 2                  NaN  55.0
# 3                Spain  80.0
# 4              Germany  82.0
# ...                ...   ...
# 927600     Netherlands  54.0
# 927601  United Kingdom  56.0
# 927602          Serbia  72.0
# 927603         Germany  75.0
# 927604          Poland  37.0
#
# [927605 rows x 10 columns]

# %%
df_matched.drop(columns=['Age of death', 'Gender_x'],inplace=True)

# %% [markdown]
# Extracting Country Name From Description

# %%
noncountry = df_matched[df_matched['Country'].isna()][['Short description', 'Country']].copy()
noncountry
# Out:
#                            Short description Country
# 1                           Baptist minister     NaN
# 2                    schrijfster (1841-1896)     NaN
# 11                             German jurist     NaN
# 17                             German jurist     NaN
# 18                             German jurist     NaN
# ...                                      ...     ...
# 927558      Australian farmer and politician     NaN
# 927580                          Opera singer     NaN
# 927583                              officier     NaN
# 927590  German World War II U-boat commander     NaN
# 927595                                   NaN     NaN
#
# [268155 rows x 2 columns]

# %%
indices = df_matched[df_matched['Country'].isna()].index

# %%
noncountry.rename(columns={'Short description': 'description'},inplace=True)
noncountry
# Out:
#                                  description Country
# 1                           Baptist minister     NaN
# 2                    schrijfster (1841-1896)     NaN
# 11                             German jurist     NaN
# 17                             German jurist     NaN
# 18                             German jurist     NaN
# ...                                      ...     ...
# 927558      Australian farmer and politician     NaN
# 927580                          Opera singer     NaN
# 927583                              officier     NaN
# 927590  German World War II U-boat commander     NaN
# 927595                                   NaN     NaN
#
# [268155 rows x 2 columns]

# %%
#declere function to extract citizenship from description
def extract_country(description, country_mapping):
    if pd.isna(description) or not isinstance(description, str):
        return None

    words = description.lower().split()

    for word in words:
        word = word.strip("(),.-")
        word_cap = word.capitalize()
        if word_cap in country_mapping:
            return country_mapping[word_cap]
        if word.startswith("schwedisch"):
            return country_mapping.get("Swedish", None)
        if word.endswith("danés"):
            return country_mapping.get("Danish", None)
        if word.startswith("russisch"):
            return country_mapping.get("Russian", None)
        if word.startswith("frans"):
            return country_mapping.get("French", None)
        if word.startswith("deutsch"):
            return country_mapping.get("German", None)
        if word.endswith("español"):
            return country_mapping.get("Spanish", None)
        if word.endswith("italiano"):
            return country_mapping.get("Italian", None)
        if word.endswith("polacu"):
            return country_mapping.get("Polish", None)
    return None

# %%
#apply extract function
noncountry['Country'] = noncountry['description'].apply(lambda desc: extract_country(desc, country_mapping))

# %%
#retrive the data after processing to orignal df
df_matched.loc[indices, 'Country'] = noncountry['Country']

# %%
df_matched.head(25)
# Out:
#                                 Name                Short description  \
# 0                     Vilém Pospíšil                 Baptist minister
# 1                     Vilém Pospíšil                 Baptist minister
# 2                    Elise Schmieden          schrijfster (1841-1896)
# 3                  Jerónimo de Rueda          Spanish baroque painter
# 4   August Karl Wilhelm Weissenbruch                    German author
# 5                  William Abbenseth                     photographer
# 6                    Anatoly Krupnov    musician and poet (1965-1997)
# 7                    Wilhelm Denhard                German politician
# 8                    Wilhelm Denhard                German politician
# 9              Francis Edwin Kilvert              Canadian politician
# 10                           Ilarion                   Russian priest
# 11                   Johannes Müller                    German jurist
# 12                   Johannes Müller                    German jurist
# 13                   Johannes Müller                    German jurist
# 14                   Johannes Müller                    German jurist
# 15                   Johannes Müller                    German jurist
# 16                   Johannes Müller                    German jurist
# 17                   Johannes Müller                    German jurist
# 18                   Johannes Müller                    German jurist
# 19                   Johannes Müller                    German jurist
# 20                   Johannes Müller                    German jurist
# 21                   Johannes Müller                    German jurist
# 22                   Johannes Müller                    German jurist
# 23                   Johannes Müller                    German jurist
# 24                       Kurt Gester  German opera singer (1914-1997)
#
#           Occupation Gender_y  Birth year  Death year         Country    Age
# 0             Pastor     Male        1873      1942.0  Czech Republic   69.0
# 1             Pastor     Male        1910      1976.0            None   66.0
# 2             Artist  Unknown        1841      1896.0            None   55.0
# 3             Artist     Male        1670      1750.0           Spain   80.0
# 4             Artist     Male        1744      1826.0         Germany   82.0
# 5             Artist     Male        1898      1972.0   United States   74.0
# 6             Artist     Male        1965      1997.0          Russia   32.0
# 7         Politician     Male        1807      1879.0         Germany   72.0
# 8         Politician     Male        1876      1944.0         Germany   68.0
# 9         Politician     Male        1838      1910.0          Canada   72.0
# 10  Religious figure  Unknown        1776      1851.0          Russia   75.0
# 11            Jurist     Male        1861      1920.0         Germany   59.0
# 12            Jurist     Male        1847      1907.0         Germany   60.0
# 13            Jurist     Male        1935      2012.0         Germany   77.0
# 14            Jurist     Male        1887      2000.0         Germany  113.0
# 15            Jurist     Male        1864      1949.0         Germany   85.0
# 16            Jurist     Male        1865      1946.0         Germany   81.0
# 17            Jurist  Unknown        1864      1932.0         Germany   68.0
# 18            Jurist     Male        1629      1684.0         Germany   55.0
# 19            Jurist  Unknown        1785      1867.0         Germany   82.0
# 20            Jurist     Male        1905      1992.0         Germany   87.0
# 21            Jurist  Unknown        1733      1816.0     Switzerland   83.0
# 22            Jurist     Male        1893      1969.0         Germany   76.0
# 23            Jurist     Male        1879      1937.0         Germany   58.0
# 24            Artist     Male        1914      1997.0         Germany   83.0

# %%
df_matched['Occupation'].isna().sum()
# Out:
# np.int64(153188)

# %%
df_matched['Occupation'].fillna('Unknown', inplace=True)

# %%
df_matched['Occupation'].isna().sum()
# Out:
# np.int64(0)

# %%
#sort by country to drop the nan country value
df_matched = df_matched.sort_values(by='Country', na_position='last')
df_matched
# Out:
#                                     Name  \
# 423965                     Ismael Balkhi
# 865813                Mohammed Asif Safi
# 223480                Félix-Henri Gosset
# 259226                         Abdul Haq
# 42586                Mohammed Daoud Khan
# ...                                  ...
# 927517  William George Player Brigstocke
# 927553            Albert III. von Winkel
# 927580          Julia Yakovlevna Makhina
# 927583                      Jānis Vēvers
# 927595              Filippa della Tavola
#
#                                         Short description          Occupation  \
# 423965                                 Political activist              Artist
# 865813                                     Afghan general  Military personnel
# 223480                                        (1830-1896)             Unknown
# 259226                                    Uyghur activist              Artist
# 42586   politician, first President of Afghanistan (19...          Politician
# ...                                                   ...                 ...
# 927517                                          1910-1940             Unknown
# 927553                              roman-catholic bishop    Religious figure
# 927580                                       Opera singer              Artist
# 927583                                           officier  Military personnel
# 927595                                                NaN             Unknown
#
#        Gender_y  Birth year  Death year      Country   Age
# 423965     Male        1918      1968.0  Afghanistan  50.0
# 865813     Male        1923      2009.0  Afghanistan  86.0
# 223480     Male        1830      1896.0  Afghanistan  66.0
# 259226     Male        1958      2001.0  Afghanistan  43.0
# 42586      Male        1909      1978.0  Afghanistan  69.0
# ...         ...         ...         ...          ...   ...
# 927517     Male        1910      1940.0         None  30.0
# 927553     Male        1300      1380.0         None  80.0
# 927580   Female        1850      1902.0         None  52.0
# 927583     Male        1899      1978.0         None  79.0
# 927595  Unknown        1395      1419.0         None  24.0
#
# [927605 rows x 8 columns]

# %%
#drop duplicates based on Name
df_matched=df_matched.drop_duplicates(subset=['Name'], keep='first')

# %%
df_matched = df_matched.sort_index()

# %%
#reset index
df_matched = df_matched.reset_index(drop=True)

# %%
df_matched.head(10)
# Out:
#                                Name                 Short description  \
# 0                   Elise Schmieden           schrijfster (1841-1896)
# 1                 Jerónimo de Rueda           Spanish baroque painter
# 2  August Karl Wilhelm Weissenbruch                     German author
# 3                 William Abbenseth                      photographer
# 4                   Anatoly Krupnov     musician and poet (1965-1997)
# 5                   Wilhelm Denhard                 German politician
# 6             Francis Edwin Kilvert               Canadian politician
# 7                           Ilarion                    Russian priest
# 8                       Kurt Gester   German opera singer (1914-1997)
# 9                      Nils Berdahl  Norwegian WW2 resistance fighter
#
#          Occupation Gender_y  Birth year  Death year        Country   Age
# 0            Artist  Unknown        1841      1896.0           None  55.0
# 1            Artist     Male        1670      1750.0          Spain  80.0
# 2            Artist     Male        1744      1826.0        Germany  82.0
# 3            Artist     Male        1898      1972.0  United States  74.0
# 4            Artist     Male        1965      1997.0         Russia  32.0
# 5        Politician     Male        1876      1944.0        Germany  68.0
# 6        Politician     Male        1838      1910.0         Canada  72.0
# 7  Religious figure  Unknown        1776      1851.0         Russia  75.0
# 8            Artist     Male        1914      1997.0        Germany  83.0
# 9           Unknown     Male        1905      1944.0         Norway  39.0

# %%
df_matched['Short description'].fillna('Unknown', inplace=True)
df_matched['Country'].fillna('Unknown', inplace=True)
# Out:
# <ipython-input-122-4c0f10b55611>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matched['Short description'].fillna('Unknown', inplace=True)
# <ipython-input-122-4c0f10b55611>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matched['Country'].fillna('Unknown', inplace=True)

# %%
#final check for NaN values in dataset
df_matched.isna().sum()
# Out:
# Name                 0
# Short description    0
# Occupation           0
# Gender_y             0
# Birth year           0
# Death year           0
# Country              0
# Age                  0
# dtype: int64

# %%
df_matched.drop(columns=['Short description','Death year','Birth year'],inplace=True)

# %% [markdown]
# #saving dataset as csv

# %%
df_matched.to_csv('cleaned_data.csv', index=True)
